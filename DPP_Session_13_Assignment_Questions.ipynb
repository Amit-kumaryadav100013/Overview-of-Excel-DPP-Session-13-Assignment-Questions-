# %% [markdown]
# #DPP-Session 13

# %% [markdown]
# **Question 1:**
# You have the following dataset:
#
# ![Q1.png](data:image/png;base64,...)
#
#
# Write a formula to calculate the total sales of Product B and Product C only.
#
# **Answer**  =SUM(B7,B8)
#
#             Where :- B7 is the address of Sales Product B.
#                      B8 is the address of Sales product C.

# %% [markdown]
# Question 2:
# What formula would you use to count the number of cells that contain numeric values in the range ?
#
# Answer:- =count(rangeof table)
#
#       =COUNT(B16:B25)
#       Where :- B16:B25 is the  Range of table

# %% [markdown]
# ![Q3.png](data:image/png;base64,...)
#
# Answer :- =AVERAGEIF(B33:B35,">80")
#
#          Where :- B33:B35 is the Address of Student Score .
#          ">80" is the Criteria.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Answer :- Select full table,
#           Go to Data → Sort
#           Level 1: Department → A to Z and Add Level then Salary → Largest to Smallest

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Answer:- =RIGHT(B54,2)
#
#           Where:- B54  is the Address of Revenue of Product .
#                   2 is the number of character you can find in the text.

# %% [markdown]
# Question 6:
# What formula would you use to count the number of employees in the "Sales" department from the dataset
# below?
# ![image.png](data:image/png;base64,...)
# Answer :- =COUNTIF(B63:B65,"Sales")
#
#           Where :- B63:B65 is the Address Range of Department.
#                     "Sales" is the Criteria.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Answer :- =SUMIF(B72:B74,">200",B72:B74)
#
#             Where :- 1st-> B72:B74 is the Address Range of unit Sold.
#                   ">200" is the criteria.
#                   2nd -> B72:B74 is the Address of Sum Range for the Unit Sold.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
#
# Answer :- =MAXIFS(B83:B85,C83:C85,"Available")
#
#         Where :- B83:B85 is the Address Range of Price.
#                  C83:C85 is the Address of Criteria Range.
#                  "Available" is the Criteria.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# Answer:- =COUNTIFS(C95:C97,">5000",B95:B97,"HR")
#
#         Where :- C95:C97 is the Addess of Criteria  Range of Salary 1st.
#                 ">5000" is the Criteria of Salary.
#                 B95:B97 is the Addess of Criteria Range of Department 2nd.
#                 "HR" is the Criteria of Department.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# Answer :- =AVERAGEIFS(C106:C108,B106:B108,">100",B106:B108,"<300")
#
#         Where:- C106:C108 is the Address of Average  Range of Sales.
#         B106:B108 is the Addess of Criteria Range 1st in price.
#         ">100" is the 1st Criteria of Price.
#          B106:B108 is the Addess of Criteria Range 2nd in price.
#         "<300" is the 2nd Criteria of Price .
